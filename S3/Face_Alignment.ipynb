# %%
# https://github.com/Urviagrawal/Facial-Landmark-Detector

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
S3_PROJECT_PATH = '/content/drive/My Drive/TSAI/TSAI-2/S3'
sys.path.append(S3_PROJECT_PATH+'/S3_Modular_Code/')
import os
os.chdir(S3_PROJECT_PATH+'/S3_Modular_Code/')

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
matplotlib.rcParams['figure.figsize'] = (6.0, 6.0)
matplotlib.rcParams['image.cmap'] = 'gray'

# %%
# get the Landmarks 68 model location
# !wget http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2 -P '/content/'
# !bzip2 -dk '/content/shape_predictor_68_face_landmarks.dat.bz2'
# Out:
# --2020-08-16 11:27:05--  http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64040097 (61M)
# Saving to: ‘/content/shape_predictor_68_face_landmarks.dat.bz2.1’
#
# shape_predictor_68_ 100%[===================>]  61.07M  5.97MB/s    in 14s
#
# 2020-08-16 11:27:20 (4.29 MB/s) - ‘/content/shape_predictor_68_face_landmarks.dat.bz2.1’ saved [64040097/64040097]
#
# bzip2: Output file /content/shape_predictor_68_face_landmarks.dat already exists.

# %%
# Face Alignment Code
# !wget http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2 -P '/content/'
# !bzip2 -dk '/content/shape_predictor_5_face_landmarks.dat.bz2'
# Out:
# --2020-08-16 10:55:27--  http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706710 (5.4M)
# Saving to: ‘/content/shape_predictor_5_face_landmarks.dat.bz2’
#
# shape_predictor_5_f 100%[===================>]   5.44M  3.51MB/s    in 1.6s
#
# 2020-08-16 10:55:28 (3.51 MB/s) - ‘/content/shape_predictor_5_face_landmarks.dat.bz2’ saved [5706710/5706710]

# %%
# !python face_landmark_detection.py --image '/content/family.jpg' --predictor '/content/shape_predictor_68_face_landmarks.dat' --output '{S3_PROJECT_PATH}'/Save_Model/ --display
# Out:
# Initializing the face detector instance
# Loading the shape predictor model
# Reading image
# <Figure size 600x600 with 1 Axes>
# Number of faces detected: 5
# Number of landmarks 68
# Saving landmarks to /content/drive/My Drive/TSAI/TSAI-2/S3/Save_Model/family_0.txt
# Saving landmarks to /content/drive/My Drive/TSAI/TSAI-2/S3/Save_Model/family_1.txt
# Saving landmarks to /content/drive/My Drive/TSAI/TSAI-2/S3/Save_Model/family_2.txt
# Saving landmarks to /content/drive/My Drive/TSAI/TSAI-2/S3/Save_Model/family_3.txt
# Saving landmarks to /content/drive/My Drive/TSAI/TSAI-2/S3/Save_Model/family_4.txt
# Saving output image to /content/drive/My Drive/TSAI/TSAI-2/S3/Save_Model/family_landmarks.jpg
# <Figure size 1500x1500 with 1 Axes>

# %%
# !python face_alignment.py --image '/content/family.jpg' --predictor '/content/shape_predictor_5_face_landmarks.dat' --output '{S3_PROJECT_PATH}'/Save_Model/ --display
# Out:
# Initializing the face detector instance
# Loading the shape predictor model
# Reading image
# <Figure size 600x600 with 1 Axes>
# Aligning Image
# Output image saved to /content/drive/My Drive/TSAI/TSAI-2/S3/Save_Model/family_aligned.jpg
# <Figure size 600x600 with 1 Axes>
